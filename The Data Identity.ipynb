# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
train_data=pd.read_csv("C:\\Users\\Ujjawal\\Anaconda3\\input_files\\DataFest_Data\\train_HK6lq50.csv")
test_data=pd.read_csv("C:\\Users\\Ujjawal\\Anaconda3\\input_files\\DataFest_Data\\test_2nAIblo.csv")
print(train_data.shape)
print(test_data.shape)
# Out:
# (73147, 16)
# (31349, 15)

# %%
train_data['age'].fillna(train_data.age.mean(),inplace=True)
train_data['trainee_engagement_rating'].fillna(2,inplace=True)
test_data['age'].fillna(test_data.age.mean(),inplace=True)
test_data['trainee_engagement_rating'].fillna(2,inplace=True)

# %%
print(train_data.age.min())
print(train_data.age.max())
print(test_data.age.min())
print(test_data.age.max())
# Out:
# 17.0
# 63.0
# 17.0
# 63.0

# %%
#Allocating age band for train data
train_data.loc[train_data['age']<=17,'age']=0
train_data.loc[(train_data['age']>17)&(train_data['age']<=27),'age']=1
train_data.loc[(train_data['age']>27)&(train_data['age']<=37),'age']=2
train_data.loc[(train_data['age']>37)&(train_data['age']<=47),'age']=3
train_data.loc[(train_data['age']>47)&(train_data['age']<=57),'age']=4
train_data.loc[train_data['age']>57,'age']=5


#Allocating age band for test data
test_data.loc[test_data['age']<=17,'age']=0
test_data.loc[(test_data['age']>17)&(test_data['age']<=27),'age']=1
test_data.loc[(test_data['age']>27)&(test_data['age']<=37),'age']=2
test_data.loc[(test_data['age']>37)&(test_data['age']<=47),'age']=3
test_data.loc[(test_data['age']>47)&(test_data['age']<=57),'age']=4
test_data.loc[test_data['age']>57,'age']=5

# %%
print(train_data.program_duration.min())
print(train_data.program_duration.max())
print(test_data.program_duration.min())
print(test_data.program_duration.max())
# Out:
# 117
# 136
# 117
# 136

# %%
train_data.loc[train_data['program_duration']<=117,'program_duration']=0
train_data.loc[(train_data['program_duration']>117)&(train_data['program_duration']<=124),'program_duration']=1
train_data.loc[(train_data['program_duration']>124)&(train_data['program_duration']<=131),'program_duration']=2
train_data.loc[train_data['program_duration']>131,'program_duration']=3
                
test_data.loc[test_data['program_duration']<=117,'program_duration']=0
test_data.loc[(test_data['program_duration']>117)&(test_data['program_duration']<=124),'program_duration']=1
test_data.loc[(test_data['program_duration']>124)&(test_data['program_duration']<=131),'program_duration']=2
test_data.loc[test_data['program_duration']>131,'program_duration']=3
               
print(train_data.head())
print(test_data.head())
# Out:
#           id program_id program_type  program_duration  test_id test_type  \
# 0   9389_150        Y_1            Y                 3      150   offline
# 1   16523_44        T_1            T                 2       44   offline
# 2  13987_178        Z_2            Z                 1      178    online
# 3   13158_32        T_2            T                 0       32   offline
# 4   10591_84        V_3            V                 2       84   offline
#
#   difficulty_level  trainee_id gender            education  city_tier  age  \
# 0     intermediate        9389      M        Matriculation          3  1.0
# 1             easy       16523      F  High School Diploma          4  1.0
# 2             easy       13987      M        Matriculation          1  3.0
# 3             easy       13158      F        Matriculation          3  2.0
# 4     intermediate       10591      F  High School Diploma          1  3.0
#
# ...

# %%
train_data.gender[train_data.gender == 'M'] = 1
train_data.gender[train_data.gender == 'F'] = 0
train_data.is_handicapped[train_data.is_handicapped=='Y']=1
train_data.is_handicapped[train_data.is_handicapped=='N']=0
train_data.education[train_data.education == 'No Qualification'] = 0
train_data.education[train_data.education == 'Matriculation'] = 1
train_data.education[train_data.education == 'High School Diploma'] = 2
train_data.education[train_data.education == 'Bachelors'] = 3
train_data.education[train_data.education == 'Masters'] = 4
train_data.difficulty_level[train_data.difficulty_level == 'easy'] = 0
train_data.difficulty_level[train_data.difficulty_level == 'intermediate'] = 1
train_data.difficulty_level[train_data.difficulty_level == 'hard'] = 2
train_data.difficulty_level[train_data.difficulty_level == 'vary hard'] = 3
train_data.test_type[train_data.test_type == 'offline'] = 0
train_data.test_type[train_data.test_type == 'online'] = 1
train_data.program_type[train_data.program_type=='S']=6
train_data.program_type[train_data.program_type=='T']=5
train_data.program_type[train_data.program_type=='U']=4
train_data.program_type[train_data.program_type=='V']=3
train_data.program_type[train_data.program_type=='X']=2
train_data.program_type[train_data.program_type=='Y']=1
train_data.program_type[train_data.program_type=='Z']=0

train_data.head()
# Out:
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
labels=train_data['id']
train_data=train_data.drop(['id','program_id','test_id','trainee_id'],axis=1)
train_data.head()
# Out:
#   program_type  program_duration test_type difficulty_level gender education  \
# 0            5                 3         0                1      1         1
# 1            1                 2         0                0      0         2
# 2            6                 1         1                0      1         1
# 3            1                 0         0                0      0         1
# 4            3                 2         0                1      0         2
#
#    city_tier  age  total_programs_enrolled is_handicapped  \
# 0          3  1.0                        5              0
# 1          4  1.0                        2              0
# 2          1  3.0                        1              0
# 3          3  2.0                        4              0
# 4          1  3.0                        2              0
#
#    trainee_engagement_rating  is_pass
# 0                        1.0        0
# 1                        3.0        1
# ...

# %%
test_data.gender[test_data.gender == 'M'] = 1
test_data.gender[test_data.gender == 'F'] = 0
test_data.is_handicapped[test_data.is_handicapped=='Y']=1
test_data.is_handicapped[test_data.is_handicapped=='N']=0
test_data.education[test_data.education == 'No Qualification'] = 0
test_data.education[test_data.education == 'Matriculation'] = 1
test_data.education[test_data.education == 'High School Diploma'] = 2
test_data.education[test_data.education == 'Bachelors'] = 3
test_data.education[test_data.education == 'Masters'] = 4
test_data.difficulty_level[test_data.difficulty_level == 'easy'] = 0
test_data.difficulty_level[test_data.difficulty_level == 'intermediate'] = 1
test_data.difficulty_level[test_data.difficulty_level == 'hard'] = 2
test_data.difficulty_level[test_data.difficulty_level == 'vary hard'] = 3
test_data.test_type[test_data.test_type == 'offline'] = 0
test_data.test_type[test_data.test_type == 'online'] = 1
test_data.program_type[test_data.program_type=='S']=6
test_data.program_type[test_data.program_type=='T']=5
test_data.program_type[test_data.program_type=='U']=4
test_data.program_type[test_data.program_type=='V']=3
test_data.program_type[test_data.program_type=='X']=2
test_data.program_type[test_data.program_type=='Y']=1
test_data.program_type[test_data.program_type=='Z']=0

test_data.head()
# Out:
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Ujjawal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
test_labels=test_data['id']
#test_data=test_data.drop(['id','program_id','test_id','trainee_id'],axis=1)
test_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-c7f11f250c69> in <module>()
# ----> 1 test_labels=test_data['id']
# ...

# %%
#X=train_data.drop('is_pass',axis=1)
Y=train_data.is_pass
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=20)

# %%
classifier=LinearRegression()
classifier.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_score=classifier.predict(X_test)
roc_auc_score(Y_test,Y_score)
# Out:
# 0.66426483027188588

# %%
predicted=classifier.predict(test_data)

# %%
submission=pd.DataFrame({"id":test_labels, "is_pass":predicted})

# %%
submission.to_csv("Data_Identity_Submission.csv", index=False)
